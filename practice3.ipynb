# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("./new/housing.csv")
# print(df)
df.head()
# df.info()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO    MEDV     B  LSTAT
# 0     15.3  396.90  4.98   24.0
# 1     17.8  396.90  9.14   21.6
# 2     17.8  392.83  4.03   34.7
# 3     18.7  394.63  2.94   33.4
# 4     18.7  396.90  5.33   36.2

# %%
# df.columns
sns.pairplot(df)

# %%
plt.scatter(df.MEDV,df.B)

# %%
plt.scatter(df.MEDV,df.LSTAT)

# %%
plt.scatter(df.MEDV,df.PTRATIO)

# %%
plt.scatter(df.MEDV,df.TAX)

# %%
plt.scatter(df.MEDV,df.RAD)

# %%
plt.scatter(df.MEDV,df.DIS)

# %%
plt.scatter(df.MEDV,df.AGE)

# %%
plt.scatter(df.MEDV,df.RM)

# %%
plt.scatter(df.MEDV,df.NOX)

# %%
plt.scatter(df.MEDV,df.CHAS)

# %%
plt.scatter(df.MEDV,df.INDUS)

# %%
plt.scatter(df.MEDV,df.ZN)

# %%
plt.scatter(df.MEDV,df.CRIM)

# %%
df_test = df.drop(['LSTAT','RM','CHAS','NOX','AGE','DIS','RAD','PTRATIO','MEDV'],axis=1)
df_test
# Out:
#         CRIM    ZN  INDUS    TAX     B
# 0    0.00632  18.0   2.31  296.0  4.98
# 1    0.02731   0.0   7.07  242.0  9.14
# 2    0.02729   0.0   7.07  242.0  4.03
# 3    0.03237   0.0   2.18  222.0  2.94
# 4    0.06905   0.0   2.18  222.0  5.33
# ..       ...   ...    ...    ...   ...
# 501  0.06263   0.0  11.93  273.0  9.67
# 502  0.04527   0.0  11.93  273.0  9.08
# 503  0.06076   0.0  11.93  273.0  5.64
# 504  0.10959   0.0  11.93  273.0  6.48
# 505  0.04741   0.0  11.93  273.0  7.88
#
# [506 rows x 5 columns]

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
model.fit(df_test,df.LSTAT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12712/343923635.py in <module>
# ----> 1 model.fit(df_test,df.LSTAT)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df_test,df.MEDV,test_size=0.2)

# %%
model.fit(x_train,y_train)

# %%
y_predicted= model.predict(x_test)
y_predicted

# %%
print(y_test.head())

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_predicted)
mse=mean_squared_error(y_test,y_predicted)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
